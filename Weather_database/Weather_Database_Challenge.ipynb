# %% [markdown]
# ## Deliverable 1. Retrieve Weather Data.
# ---
# 1. Generate a new set of 2000 random latitudes and longitudes.
# 2. Get the nearest city.
# 3. Perform an API call with the OpenWeatherMap.
# 4. Retrieve the following information from the API call.
#     - The latitude and longitude
#     - The maximum temperature
#     - The % humidity
#     - The % cloudiness
#     - The Wind speed
#     - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.
# 5. Add the data to a new DataFrame.
# 6. Save the new DataFrame as a CSV file.

# %%
from citipy import citipy
import numpy as np
import pandas as pd

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []


# Identify nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 739

# %%
# Import the requests library.
import requests

# Import the datetime module from the datetime library.
from datetime import datetime

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ### Retrieve the following information from the API call.
#     - The latitude and longitude
#     - The Max temperature
#     - The % humidity
#     - The % cloudiness
#     - The Wind speed
#     - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]       
            
            # Append the City information into city_data list
        city_data.append({"City": city.title(), 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Current Description": city_weather_description,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})
    # If an error is experienced, skip the city

    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | erzin
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | praia da vitoria
# Processing Record 4 of Set 1 | guarapari
# Processing Record 5 of Set 1 | saint george
# Processing Record 6 of Set 1 | xining
# Processing Record 7 of Set 1 | puerto colombia
# Processing Record 8 of Set 1 | flinders
# Processing Record 9 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 10 of Set 1 | teya
# Processing Record 11 of Set 1 | aspros
# Processing Record 12 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 1 | yellowknife
# Processing Record 14 of Set 1 | butaritari
# Processing Record 15 of Set 1 | jamestown
# Processing Record 16 of Set 1 | puerto ayora
# Processing Record 17 of Set 1 | utiroa
# City not found. Skipping...
# Processing Record 18 of Set 1 | mar del plata
# Processing Record 19 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 20 of Set 1 | ivybridge
# Processing Record 21 of Set 1 | georgetown
# Processing Record 22 of Set 1 | hithadhoo
# Processing Record 23 of Set 1 | ponta do sol
# Processing Record 24 of Set 1 | bluff
# Processing Record 25 of Set 1 | hobart
# Processing Record 26 of Set 1 | roma
# Processing Record 27 of Set 1 | busselton
# Processing Record 28 of Set 1 | esperance
# Processing Record 29 of Set 1 | bredasdorp
# Processing Record 30 of Set 1 | moen
# Processing Record 31 of Set 1 | behshahr
# Processing Record 32 of Set 1 | lompoc
# Processing Record 33 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 34 of Set 1 | coquimbo
# Processing Record 35 of Set 1 | pinheiro machado
# Processing Record 36 of Set 1 | cape town
# Processing Record 37 of Set 1 | east london
# Processing Record 38 of Set 1 | port alfred
# Processing Record 39 of Set 1 | leningradskiy
# Processing Record 40 of Set 1 | usinsk
# Processing Record 41 of Set 1 | hamilton
# Processing Record 42 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 43 of Set 1 | qaanaaq
# Processing Record 44 of Set 1 | souillac
# Processing Record 45 of Set 1 | lavrentiya
# Processing Record 46 of Set 1 | mahebourg
# Processing Record 47 of Set 1 | mataura
# Processing Record 48 of Set 1 | benguela
# Processing Record 49 of Set 1 | olutanga
# Processing Record 50 of Set 1 | punta arenas
# Processing Record 1 of Set 2 | mayo
# Processing Record 2 of Set 2 | ushuaia
# Processing Record 3 of Set 2 | folkestone
# Processing Record 4 of Set 2 | vestmannaeyjar
# Processing Record 5 of Set 2 | clearlake
# Processing Record 6 of Set 2 | lagoa
# Processing Record 7 of Set 2 | poum
# Processing Record 8 of Set 2 | nieuw amsterdam
# Processing Record 9 of Set 2 | atuona
# Processing Record 10 of Set 2 | thompson
# Processing Record 11 of Set 2 | longlac
# City not found. Skipping...
# Processing Record 12 of Set 2 | vaini
# Processing Record 13 of Set 2 | nikolskoye
# Processing Record 14 of Set 2 | hongjiang
# Processing Record 15 of Set 2 | burns lake
# Processing Record 16 of Set 2 | kapaa
# Processing Record 17 of Set 2 | hermanus
# Processing Record 18 of Set 2 | hilo
# Processing Record 19 of Set 2 | toliary
# City not found. Skipping...
# Processing Record 20 of Set 2 | chima
# Processing Record 21 of Set 2 | grand gaube
# Processing Record 22 of Set 2 | evensk
# Processing Record 23 of Set 2 | rocha
# Processing Record 24 of Set 2 | kavieng
# Processing Record 25 of Set 2 | naze
# Processing Record 26 of Set 2 | broome
# Processing Record 27 of Set 2 | arraial do cabo
# Processing Record 28 of Set 2 | rajapur
# Processing Record 29 of Set 2 | yablonovo
# Processing Record 30 of Set 2 | vestmanna
# Processing Record 31 of Set 2 | biak
# Processing Record 32 of Set 2 | eydhafushi
# Processing Record 33 of Set 2 | ko samui
# Processing Record 34 of Set 2 | morant bay
# Processing Record 35 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 36 of Set 2 | frederick
# Processing Record 37 of Set 2 | albany
# Processing Record 38 of Set 2 | namibe
# Processing Record 39 of Set 2 | niamey
# Processing Record 40 of Set 2 | dallas
# Processing Record 41 of Set 2 | port hedland
# Processing Record 42 of Set 2 | lodingen
# Processing Record 43 of Set 2 | latung
# Processing Record 44 of Set 2 | faanui
# Processing Record 45 of Set 2 | grindavik
# Processing Record 46 of Set 2 | finnsnes
# Processing Record 47 of Set 2 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 48 of Set 2 | atar
# Processing Record 49 of Set 2 | vila velha
# Processing Record 50 of Set 2 | ust-nera
# Processing Record 1 of Set 3 | kouvola
# Processing Record 2 of Set 3 | bethel
# Processing Record 3 of Set 3 | upernavik
# Processing Record 4 of Set 3 | dingle
# Processing Record 5 of Set 3 | tuktoyaktuk
# Processing Record 6 of Set 3 | cidreira
# Processing Record 7 of Set 3 | lorengau
# Processing Record 8 of Set 3 | porto walter
# Processing Record 9 of Set 3 | veraval
# Processing Record 10 of Set 3 | ballina
# Processing Record 11 of Set 3 | tasiilaq
# Processing Record 12 of Set 3 | ancud
# Processing Record 13 of Set 3 | zvishavane
# Processing Record 14 of Set 3 | dikson
# Processing Record 15 of Set 3 | cayenne
# Processing Record 16 of Set 3 | teeli
# Processing Record 17 of Set 3 | sucua
# Processing Record 18 of Set 3 | salalah
# Processing Record 19 of Set 3 | camacha
# Processing Record 20 of Set 3 | dunedin
# Processing Record 21 of Set 3 | maur
# Processing Record 22 of Set 3 | aflu
# City not found. Skipping...
# Processing Record 23 of Set 3 | visegrad
# Processing Record 24 of Set 3 | nyurba
# Processing Record 25 of Set 3 | mafinga
# Processing Record 26 of Set 3 | chokurdakh
# Processing Record 27 of Set 3 | bengkulu
# Processing Record 28 of Set 3 | chuy
# Processing Record 29 of Set 3 | carquefou
# Processing Record 30 of Set 3 | torbay
# Processing Record 31 of Set 3 | samarinda
# Processing Record 32 of Set 3 | haines junction
# Processing Record 33 of Set 3 | carnarvon
# Processing Record 34 of Set 3 | imbituba
# Processing Record 35 of Set 3 | collie
# Processing Record 36 of Set 3 | castro
# Processing Record 37 of Set 3 | iqaluit
# Processing Record 38 of Set 3 | hluti
# Processing Record 39 of Set 3 | nouadhibou
# Processing Record 40 of Set 3 | kruisfontein
# Processing Record 41 of Set 3 | saint-felicien
# Processing Record 42 of Set 3 | port elizabeth
# Processing Record 43 of Set 3 | kodiak
# Processing Record 44 of Set 3 | nome
# Processing Record 45 of Set 3 | san antonio
# Processing Record 46 of Set 3 | khonuu
# City not found. Skipping...
# Processing Record 47 of Set 3 | barcelos
# Processing Record 48 of Set 3 | aklavik
# Processing Record 49 of Set 3 | urshelskiy
# Processing Record 50 of Set 3 | scicli
# Processing Record 1 of Set 4 | launceston
# Processing Record 2 of Set 4 | poronaysk
# Processing Record 3 of Set 4 | marawi
# Processing Record 4 of Set 4 | santa isabel
# Processing Record 5 of Set 4 | santa cruz
# Processing Record 6 of Set 4 | batemans bay
# Processing Record 7 of Set 4 | saint anthony
# Processing Record 8 of Set 4 | saint-philippe
# Processing Record 9 of Set 4 | vanimo
# Processing Record 10 of Set 4 | barrow
# Processing Record 11 of Set 4 | damghan
# Processing Record 12 of Set 4 | lishui
# Processing Record 13 of Set 4 | diban
# Processing Record 14 of Set 4 | asosa
# Processing Record 15 of Set 4 | luderitz
# Processing Record 16 of Set 4 | katsuura
# Processing Record 17 of Set 4 | borba
# Processing Record 18 of Set 4 | havre-saint-pierre
# Processing Record 19 of Set 4 | maua
# Processing Record 20 of Set 4 | saldanha
# Processing Record 21 of Set 4 | mporokoso
# Processing Record 22 of Set 4 | thai binh
# Processing Record 23 of Set 4 | jalu
# Processing Record 24 of Set 4 | chapais
# Processing Record 25 of Set 4 | namie
# Processing Record 26 of Set 4 | kerteh
# City not found. Skipping...
# Processing Record 27 of Set 4 | sabang
# Processing Record 28 of Set 4 | frankfort
# Processing Record 29 of Set 4 | hambantota
# Processing Record 30 of Set 4 | sur
# Processing Record 31 of Set 4 | khandyga
# Processing Record 32 of Set 4 | dawlatabad
# Processing Record 33 of Set 4 | yulara
# Processing Record 34 of Set 4 | mayumba
# Processing Record 35 of Set 4 | airai
# Processing Record 36 of Set 4 | floro
# Processing Record 37 of Set 4 | faya
# Processing Record 38 of Set 4 | najran
# Processing Record 39 of Set 4 | aykhal
# Processing Record 40 of Set 4 | anadyr
# Processing Record 41 of Set 4 | victoria
# Processing Record 42 of Set 4 | chachapoyas
# Processing Record 43 of Set 4 | palmer
# Processing Record 44 of Set 4 | bonthe
# Processing Record 45 of Set 4 | karaton
# Processing Record 46 of Set 4 | bathsheba
# Processing Record 47 of Set 4 | ostrovnoy
# Processing Record 48 of Set 4 | avarua
# Processing Record 49 of Set 4 | bambous virieux
# Processing Record 50 of Set 4 | vanavara
# Processing Record 1 of Set 5 | rognan
# Processing Record 2 of Set 5 | alice springs
# Processing Record 3 of Set 5 | bilibino
# Processing Record 4 of Set 5 | baculin
# Processing Record 5 of Set 5 | sokoto
# Processing Record 6 of Set 5 | hohhot
# Processing Record 7 of Set 5 | buraydah
# Processing Record 8 of Set 5 | rawson
# Processing Record 9 of Set 5 | talnakh
# Processing Record 10 of Set 5 | tabialan
# City not found. Skipping...
# Processing Record 11 of Set 5 | pevek
# Processing Record 12 of Set 5 | sao joao da barra
# Processing Record 13 of Set 5 | pestyaki
# Processing Record 14 of Set 5 | vaitape
# Processing Record 15 of Set 5 | husavik
# Processing Record 16 of Set 5 | rio bravo
# Processing Record 17 of Set 5 | kegayli
# City not found. Skipping...
# Processing Record 18 of Set 5 | port blair
# Processing Record 19 of Set 5 | fortuna
# Processing Record 20 of Set 5 | new london
# Processing Record 21 of Set 5 | artyk
# City not found. Skipping...
# Processing Record 22 of Set 5 | lebu
# Processing Record 23 of Set 5 | auki
# Processing Record 24 of Set 5 | kaitangata
# Processing Record 25 of Set 5 | laguna
# Processing Record 26 of Set 5 | tiksi
# Processing Record 27 of Set 5 | fomboni
# Processing Record 28 of Set 5 | la mana
# Processing Record 29 of Set 5 | malartic
# Processing Record 30 of Set 5 | burnie
# Processing Record 31 of Set 5 | mersing
# Processing Record 32 of Set 5 | katra
# Processing Record 33 of Set 5 | suleja
# Processing Record 34 of Set 5 | santa cruz del sur
# Processing Record 35 of Set 5 | vuktyl
# Processing Record 36 of Set 5 | iralaya
# Processing Record 37 of Set 5 | ucluelet
# Processing Record 38 of Set 5 | cabo san lucas
# Processing Record 39 of Set 5 | llanes
# Processing Record 40 of Set 5 | kungurtug
# Processing Record 41 of Set 5 | san patricio
# Processing Record 42 of Set 5 | baykit
# Processing Record 43 of Set 5 | severo-kurilsk
# Processing Record 44 of Set 5 | tarko-sale
# Processing Record 45 of Set 5 | sitka
# Processing Record 46 of Set 5 | puri
# Processing Record 47 of Set 5 | smithers
# Processing Record 48 of Set 5 | anar darreh
# City not found. Skipping...
# Processing Record 49 of Set 5 | sioux lookout
# Processing Record 50 of Set 5 | longyearbyen
# Processing Record 1 of Set 6 | qaqortoq
# Processing Record 2 of Set 6 | zhigalovo
# Processing Record 3 of Set 6 | florianopolis
# Processing Record 4 of Set 6 | tanout
# Processing Record 5 of Set 6 | barcarena
# Processing Record 6 of Set 6 | kuanshan
# City not found. Skipping...
# Processing Record 7 of Set 6 | kieta
# Processing Record 8 of Set 6 | walvis bay
# Processing Record 9 of Set 6 | shumskiy
# Processing Record 10 of Set 6 | emba
# Processing Record 11 of Set 6 | asfi
# Processing Record 12 of Set 6 | vardo
# Processing Record 13 of Set 6 | werda
# Processing Record 14 of Set 6 | kenora
# Processing Record 15 of Set 6 | san andres
# Processing Record 16 of Set 6 | nanortalik
# Processing Record 17 of Set 6 | port hawkesbury
# Processing Record 18 of Set 6 | rangapara
# Processing Record 19 of Set 6 | adrar
# Processing Record 20 of Set 6 | vaxjo
# Processing Record 21 of Set 6 | nanjing
# Processing Record 22 of Set 6 | oeiras
# Processing Record 23 of Set 6 | mogadishu
# Processing Record 24 of Set 6 | makakilo city
# Processing Record 25 of Set 6 | deputatskiy
# Processing Record 26 of Set 6 | los llanos de aridane
# Processing Record 27 of Set 6 | hope
# Processing Record 28 of Set 6 | voh
# Processing Record 29 of Set 6 | gonbad-e qabus
# Processing Record 30 of Set 6 | inhambane
# Processing Record 31 of Set 6 | sao miguel do araguaia
# Processing Record 32 of Set 6 | cuauhtemoc
# Processing Record 33 of Set 6 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 34 of Set 6 | kyshtovka
# Processing Record 35 of Set 6 | provideniya
# Processing Record 36 of Set 6 | lyubeshiv
# City not found. Skipping...
# Processing Record 37 of Set 6 | nuuk
# Processing Record 38 of Set 6 | te anau
# Processing Record 39 of Set 6 | puerto escondido
# Processing Record 40 of Set 6 | minot
# Processing Record 41 of Set 6 | kedrovyy
# Processing Record 42 of Set 6 | barcelona
# Processing Record 43 of Set 6 | sterling
# Processing Record 44 of Set 6 | kantilo
# Processing Record 45 of Set 6 | comodoro rivadavia
# Processing Record 46 of Set 6 | zhangye
# Processing Record 47 of Set 6 | meshchovsk
# Processing Record 48 of Set 6 | necochea
# Processing Record 49 of Set 6 | cruz
# Processing Record 50 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 1 of Set 7 | sao filipe
# Processing Record 2 of Set 7 | tucurui
# Processing Record 3 of Set 7 | caconda
# Processing Record 4 of Set 7 | coihaique
# Processing Record 5 of Set 7 | axim
# Processing Record 6 of Set 7 | garowe
# Processing Record 7 of Set 7 | saskylakh
# Processing Record 8 of Set 7 | paka
# Processing Record 9 of Set 7 | vezirkopru
# Processing Record 10 of Set 7 | kashmor
# Processing Record 11 of Set 7 | general cepeda
# Processing Record 12 of Set 7 | kenai
# Processing Record 13 of Set 7 | bandarbeyla
# Processing Record 14 of Set 7 | palmas de monte alto
# Processing Record 15 of Set 7 | denpasar
# Processing Record 16 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 17 of Set 7 | sal rei
# Processing Record 18 of Set 7 | nantucket
# Processing Record 19 of Set 7 | pangody
# Processing Record 20 of Set 7 | christchurch
# Processing Record 21 of Set 7 | loa janan
# Processing Record 22 of Set 7 | labutta
# City not found. Skipping...
# Processing Record 23 of Set 7 | encheng
# Processing Record 24 of Set 7 | ngara
# Processing Record 25 of Set 7 | hovd
# Processing Record 26 of Set 7 | tiarei
# Processing Record 27 of Set 7 | riyadh
# Processing Record 28 of Set 7 | tura
# Processing Record 29 of Set 7 | dickson
# Processing Record 30 of Set 7 | codrington
# Processing Record 31 of Set 7 | nanakuli
# Processing Record 32 of Set 7 | itarema
# Processing Record 33 of Set 7 | karamea
# City not found. Skipping...
# Processing Record 34 of Set 7 | tongchuan
# Processing Record 35 of Set 7 | khatanga
# Processing Record 36 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 37 of Set 7 | along
# Processing Record 38 of Set 7 | muros
# Processing Record 39 of Set 7 | hobyo
# Processing Record 40 of Set 7 | port hardy
# Processing Record 41 of Set 7 | wuwei
# Processing Record 42 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 43 of Set 7 | cap malheureux
# Processing Record 44 of Set 7 | lata
# Processing Record 45 of Set 7 | nargana
# Processing Record 46 of Set 7 | kahului
# Processing Record 47 of Set 7 | palana
# Processing Record 48 of Set 7 | chenghai
# Processing Record 49 of Set 7 | sandpoint
# Processing Record 50 of Set 7 | nabire
# Processing Record 1 of Set 8 | nalut
# Processing Record 2 of Set 8 | new norfolk
# Processing Record 3 of Set 8 | asau
# Processing Record 4 of Set 8 | nueva loja
# Processing Record 5 of Set 8 | binzhou
# Processing Record 6 of Set 8 | san quintin
# Processing Record 7 of Set 8 | juneau
# Processing Record 8 of Set 8 | mikun
# Processing Record 9 of Set 8 | yabelo
# Processing Record 10 of Set 8 | bhinmal
# Processing Record 11 of Set 8 | shache
# Processing Record 12 of Set 8 | ilulissat
# Processing Record 13 of Set 8 | qandala
# Processing Record 14 of Set 8 | loncoche
# Processing Record 15 of Set 8 | huaicheng
# Processing Record 16 of Set 8 | grootfontein
# Processing Record 17 of Set 8 | hofn
# Processing Record 18 of Set 8 | meulaboh
# Processing Record 19 of Set 8 | abonnema
# Processing Record 20 of Set 8 | libertador general san martin
# Processing Record 21 of Set 8 | kendari
# Processing Record 22 of Set 8 | fort nelson
# Processing Record 23 of Set 8 | yar-sale
# Processing Record 24 of Set 8 | klaksvik
# Processing Record 25 of Set 8 | beloha
# Processing Record 26 of Set 8 | eureka
# Processing Record 27 of Set 8 | xuddur
# Processing Record 28 of Set 8 | oranjemund
# Processing Record 29 of Set 8 | hasaki
# Processing Record 30 of Set 8 | whitianga
# Processing Record 31 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 32 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 33 of Set 8 | aripuana
# Processing Record 34 of Set 8 | yarega
# Processing Record 35 of Set 8 | agadez
# Processing Record 36 of Set 8 | berlevag
# Processing Record 37 of Set 8 | makung
# City not found. Skipping...
# Processing Record 38 of Set 8 | banda aceh
# Processing Record 39 of Set 8 | port macquarie
# Processing Record 40 of Set 8 | vila
# Processing Record 41 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 42 of Set 8 | kamennomostskoye
# Processing Record 43 of Set 8 | chardara
# Processing Record 44 of Set 8 | sayansk
# Processing Record 45 of Set 8 | arnissa
# Processing Record 46 of Set 8 | rolim de moura
# City not found. Skipping...
# Processing Record 47 of Set 8 | cheremkhovo
# Processing Record 48 of Set 8 | oktyabrskoye
# Processing Record 49 of Set 8 | turukhansk
# Processing Record 50 of Set 8 | west bay
# Processing Record 1 of Set 9 | tigil
# Processing Record 2 of Set 9 | anchorage
# Processing Record 3 of Set 9 | cherskiy
# Processing Record 4 of Set 9 | valparaiso
# Processing Record 5 of Set 9 | luzhou
# Processing Record 6 of Set 9 | karkaralinsk
# City not found. Skipping...
# Processing Record 7 of Set 9 | mount gambier
# Processing Record 8 of Set 9 | maceio
# Processing Record 9 of Set 9 | westport
# Processing Record 10 of Set 9 | raga
# Processing Record 11 of Set 9 | dixon
# Processing Record 12 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 13 of Set 9 | karratha
# Processing Record 14 of Set 9 | houma
# Processing Record 15 of Set 9 | labuhan
# Processing Record 16 of Set 9 | negombo
# Processing Record 17 of Set 9 | quang ngai
# Processing Record 18 of Set 9 | oktyabrskiy
# Processing Record 19 of Set 9 | akranes
# Processing Record 20 of Set 9 | mae hong son
# Processing Record 21 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 22 of Set 9 | berdigestyakh
# Processing Record 23 of Set 9 | beyneu
# Processing Record 24 of Set 9 | kapit
# Processing Record 25 of Set 9 | osa
# Processing Record 26 of Set 9 | gilazi
# City not found. Skipping...
# Processing Record 27 of Set 9 | huambo
# Processing Record 28 of Set 9 | chapeco
# Processing Record 29 of Set 9 | sobolevo
# Processing Record 30 of Set 9 | constitucion
# Processing Record 31 of Set 9 | agapovka
# Processing Record 32 of Set 9 | cha grande
# Processing Record 33 of Set 9 | muravlenko
# Processing Record 34 of Set 9 | henties bay
# Processing Record 35 of Set 9 | dubbo
# Processing Record 36 of Set 9 | buon me thuot
# City not found. Skipping...
# Processing Record 37 of Set 9 | basoko
# Processing Record 38 of Set 9 | gharo
# Processing Record 39 of Set 9 | high level
# Processing Record 40 of Set 9 | ye
# City not found. Skipping...
# Processing Record 41 of Set 9 | mezen
# Processing Record 42 of Set 9 | lufilufi
# Processing Record 43 of Set 9 | arkhangelsk
# Processing Record 44 of Set 9 | kloulklubed
# Processing Record 45 of Set 9 | seymchan
# Processing Record 46 of Set 9 | iquique
# Processing Record 47 of Set 9 | lavumisa
# Processing Record 48 of Set 9 | ankang
# Processing Record 49 of Set 9 | pisco
# Processing Record 50 of Set 9 | raudeberg
# Processing Record 1 of Set 10 | lhokseumawe
# Processing Record 2 of Set 10 | gayeri
# Processing Record 3 of Set 10 | vao
# Processing Record 4 of Set 10 | casambalangan
# Processing Record 5 of Set 10 | boyolangu
# Processing Record 6 of Set 10 | ukiah
# Processing Record 7 of Set 10 | namatanai
# Processing Record 8 of Set 10 | kota tinggi
# Processing Record 9 of Set 10 | santana do livramento
# Processing Record 10 of Set 10 | itainopolis
# Processing Record 11 of Set 10 | synya
# Processing Record 12 of Set 10 | umm lajj
# Processing Record 13 of Set 10 | bischofswerda
# Processing Record 14 of Set 10 | sredniy ikorets
# Processing Record 15 of Set 10 | samarai
# Processing Record 16 of Set 10 | kadykchan
# City not found. Skipping...
# Processing Record 17 of Set 10 | yankton
# Processing Record 18 of Set 10 | san juan de uraba
# Processing Record 19 of Set 10 | radom
# Processing Record 20 of Set 10 | ruteng
# Processing Record 21 of Set 10 | kondinskoye
# Processing Record 22 of Set 10 | bloomington
# Processing Record 23 of Set 10 | formoso do araguaia
# City not found. Skipping...
# Processing Record 24 of Set 10 | kavaratti
# Processing Record 25 of Set 10 | marsh harbour
# Processing Record 26 of Set 10 | pathein
# Processing Record 27 of Set 10 | hami
# Processing Record 28 of Set 10 | kinkala
# Processing Record 29 of Set 10 | sydney
# Processing Record 30 of Set 10 | dryden
# Processing Record 31 of Set 10 | mutsamudu
# City not found. Skipping...
# Processing Record 32 of Set 10 | nizhneyansk
# City not found. Skipping...
# Processing Record 33 of Set 10 | srednekolymsk
# Processing Record 34 of Set 10 | cornelio procopio
# Processing Record 35 of Set 10 | milkovo
# Processing Record 36 of Set 10 | goderich
# Processing Record 37 of Set 10 | save
# Processing Record 38 of Set 10 | maumere
# Processing Record 39 of Set 10 | south bend
# Processing Record 40 of Set 10 | sechura
# Processing Record 41 of Set 10 | joshimath
# Processing Record 42 of Set 10 | peto
# Processing Record 43 of Set 10 | perth
# Processing Record 44 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 45 of Set 10 | davila
# Processing Record 46 of Set 10 | krasnoselkup
# Processing Record 47 of Set 10 | konstantinovka
# Processing Record 48 of Set 10 | daigo
# Processing Record 49 of Set 10 | ariquemes
# Processing Record 50 of Set 10 | flagstaff
# Processing Record 1 of Set 11 | vengerovo
# Processing Record 2 of Set 11 | aguas vermelhas
# Processing Record 3 of Set 11 | timra
# Processing Record 4 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 5 of Set 11 | cortes
# Processing Record 6 of Set 11 | norman wells
# Processing Record 7 of Set 11 | yanji
# Processing Record 8 of Set 11 | margate
# Processing Record 9 of Set 11 | osakarovka
# Processing Record 10 of Set 11 | fairbanks
# Processing Record 11 of Set 11 | kanzaki
# Processing Record 12 of Set 11 | seoul
# Processing Record 13 of Set 11 | bubaque
# Processing Record 14 of Set 11 | seydi
# Processing Record 15 of Set 11 | charters towers
# Processing Record 16 of Set 11 | aginskoye
# Processing Record 17 of Set 11 | abrau-dyurso
# Processing Record 18 of Set 11 | kindu
# Processing Record 19 of Set 11 | lubango
# Processing Record 20 of Set 11 | port-gentil
# Processing Record 21 of Set 11 | mao
# Processing Record 22 of Set 11 | kohima
# Processing Record 23 of Set 11 | ahipara
# Processing Record 24 of Set 11 | baringo
# Processing Record 25 of Set 11 | guerrero negro
# Processing Record 26 of Set 11 | qui nhon
# Processing Record 27 of Set 11 | rafaela
# Processing Record 28 of Set 11 | businga
# Processing Record 29 of Set 11 | salvador
# Processing Record 30 of Set 11 | eidsvag
# Processing Record 31 of Set 11 | geraldton
# Processing Record 32 of Set 11 | gorontalo
# Processing Record 33 of Set 11 | eyl
# Processing Record 34 of Set 11 | miracema
# Processing Record 35 of Set 11 | nogales
# Processing Record 36 of Set 11 | russell
# Processing Record 37 of Set 11 | aitape
# Processing Record 38 of Set 11 | reconquista
# Processing Record 39 of Set 11 | zyryanka
# Processing Record 40 of Set 11 | hirara
# Processing Record 41 of Set 11 | jatiroto
# Processing Record 42 of Set 11 | vila franca do campo
# Processing Record 43 of Set 11 | alofi
# Processing Record 44 of Set 11 | mahadday weyne
# City not found. Skipping...
# Processing Record 45 of Set 11 | san borja
# Processing Record 46 of Set 11 | maltahohe
# Processing Record 47 of Set 11 | krasnomayskiy
# Processing Record 48 of Set 11 | rajapolah
# Processing Record 49 of Set 11 | hanzhong
# Processing Record 50 of Set 11 | almaznyy
# Processing Record 1 of Set 12 | beirut
# Processing Record 2 of Set 12 | khangarh
# Processing Record 3 of Set 12 | itoman
# Processing Record 4 of Set 12 | half moon bay
# Processing Record 5 of Set 12 | southbridge
# Processing Record 6 of Set 12 | inirida
# Processing Record 7 of Set 12 | nelson bay
# Processing Record 8 of Set 12 | egvekinot
# Processing Record 9 of Set 12 | chino valley
# Processing Record 10 of Set 12 | ferrol
# Processing Record 11 of Set 12 | winnemucca
# Processing Record 12 of Set 12 | cartagena del chaira
# Processing Record 13 of Set 12 | udachnyy
# Processing Record 14 of Set 12 | ingham
# Processing Record 15 of Set 12 | kayes
# Processing Record 16 of Set 12 | la ronge
# Processing Record 17 of Set 12 | tuy hoa
# Processing Record 18 of Set 12 | moba
# Processing Record 19 of Set 12 | tautira
# Processing Record 20 of Set 12 | thunder bay
# Processing Record 21 of Set 12 | kutum
# Processing Record 22 of Set 12 | ust-ilimsk
# Processing Record 23 of Set 12 | tuatapere
# Processing Record 24 of Set 12 | gazanjyk
# Processing Record 25 of Set 12 | emerald
# Processing Record 26 of Set 12 | thoen
# Processing Record 27 of Set 12 | conde
# Processing Record 28 of Set 12 | mattru
# Processing Record 29 of Set 12 | port lincoln
# Processing Record 30 of Set 12 | kapan
# Processing Record 31 of Set 12 | kryve ozero
# Processing Record 32 of Set 12 | progreso
# Processing Record 33 of Set 12 | carauari
# Processing Record 34 of Set 12 | price
# Processing Record 35 of Set 12 | moose factory
# Processing Record 36 of Set 12 | santa rita do sapucai
# Processing Record 37 of Set 12 | ribeira grande
# Processing Record 38 of Set 12 | praia
# Processing Record 39 of Set 12 | atlantic city
# Processing Record 40 of Set 12 | jiroft
# City not found. Skipping...
# Processing Record 41 of Set 12 | ust-kulom
# Processing Record 42 of Set 12 | mattawa
# Processing Record 43 of Set 12 | toms river
# Processing Record 44 of Set 12 | svetlyy
# Processing Record 45 of Set 12 | shingu
# Processing Record 46 of Set 12 | lodwar
# Processing Record 47 of Set 12 | vizianagaram
# Processing Record 48 of Set 12 | biu
# Processing Record 49 of Set 12 | castro verde
# Processing Record 50 of Set 12 | kurud
# Processing Record 1 of Set 13 | nishihara
# Processing Record 2 of Set 13 | salym
# Processing Record 3 of Set 13 | narsaq
# Processing Record 4 of Set 13 | gobabis
# Processing Record 5 of Set 13 | divo
# Processing Record 6 of Set 13 | pemba
# Processing Record 7 of Set 13 | coahuayana
# Processing Record 8 of Set 13 | xinzhou
# Processing Record 9 of Set 13 | diamantino
# Processing Record 10 of Set 13 | wahran
# City not found. Skipping...
# Processing Record 11 of Set 13 | todos santos
# Processing Record 12 of Set 13 | solnechnyy
# Processing Record 13 of Set 13 | atyrau
# Processing Record 14 of Set 13 | surin
# Processing Record 15 of Set 13 | katobu
# Processing Record 16 of Set 13 | krasnokamensk
# Processing Record 17 of Set 13 | maniitsoq
# Processing Record 18 of Set 13 | bodden town
# Processing Record 19 of Set 13 | mahon
# Processing Record 20 of Set 13 | savannah bight
# Processing Record 21 of Set 13 | mackay
# Processing Record 22 of Set 13 | tazovskiy
# Processing Record 23 of Set 13 | tucuman
# Processing Record 24 of Set 13 | pochutla
# Processing Record 25 of Set 13 | ulaangom
# Processing Record 26 of Set 13 | portland
# Processing Record 27 of Set 13 | rocky mountain house
# Processing Record 28 of Set 13 | akdepe
# Processing Record 29 of Set 13 | bela
# Processing Record 30 of Set 13 | gidole
# Processing Record 31 of Set 13 | alim
# Processing Record 32 of Set 13 | rio gallegos
# Processing Record 33 of Set 13 | klyuchi
# Processing Record 34 of Set 13 | babushkin
# Processing Record 35 of Set 13 | labytnangi
# Processing Record 36 of Set 13 | igarape-acu
# City not found. Skipping...
# Processing Record 37 of Set 13 | pousat
# City not found. Skipping...
# Processing Record 38 of Set 13 | manicore
# Processing Record 39 of Set 13 | saint-francois
# Processing Record 40 of Set 13 | ormara
# Processing Record 41 of Set 13 | padang
# Processing Record 42 of Set 13 | jishou
# Processing Record 43 of Set 13 | andilamena
# Processing Record 44 of Set 13 | angoche
# Processing Record 45 of Set 13 | chato
# Processing Record 46 of Set 13 | wakkanai
# Processing Record 47 of Set 13 | porto novo
# Processing Record 48 of Set 13 | moji das cruzes
# City not found. Skipping...
# Processing Record 49 of Set 13 | cochrane
# Processing Record 50 of Set 13 | west wendover
# Processing Record 1 of Set 14 | ambodifototra
# City not found. Skipping...
# Processing Record 2 of Set 14 | ambon
# Processing Record 3 of Set 14 | bikramganj
# Processing Record 4 of Set 14 | puerto del rosario
# Processing Record 5 of Set 14 | sao jose da coroa grande
# Processing Record 6 of Set 14 | medvedka
# Processing Record 7 of Set 14 | leirvik
# Processing Record 8 of Set 14 | tampere
# Processing Record 9 of Set 14 | the valley
# Processing Record 10 of Set 14 | yangambi
# Processing Record 11 of Set 14 | cap-aux-meules
# Processing Record 12 of Set 14 | lanzhou
# Processing Record 13 of Set 14 | araouane
# Processing Record 14 of Set 14 | opuwo
# Processing Record 15 of Set 14 | skjervoy
# Processing Record 16 of Set 14 | kamaishi
# Processing Record 17 of Set 14 | olafsvik
# Processing Record 18 of Set 14 | reinosa
# Processing Record 19 of Set 14 | prachuap khiri khan
# Processing Record 20 of Set 14 | san policarpo
# Processing Record 21 of Set 14 | flin flon
# Processing Record 22 of Set 14 | soe
# Processing Record 23 of Set 14 | bocaranga
# City not found. Skipping...
# Processing Record 24 of Set 14 | zhezkazgan
# Processing Record 25 of Set 14 | mana
# Processing Record 26 of Set 14 | puerto madryn
# Processing Record 27 of Set 14 | gat
# Processing Record 28 of Set 14 | biltine
# Processing Record 29 of Set 14 | isangel
# Processing Record 30 of Set 14 | marcona
# City not found. Skipping...
# Processing Record 31 of Set 14 | pimentel
# Processing Record 32 of Set 14 | parry sound
# Processing Record 33 of Set 14 | gamba
# Processing Record 34 of Set 14 | merauke
# Processing Record 35 of Set 14 | goundam
# Processing Record 36 of Set 14 | kaeo
# Processing Record 37 of Set 14 | yacuiba
# Processing Record 38 of Set 14 | sistranda
# Processing Record 39 of Set 14 | krasnoyarsk-45
# City not found. Skipping...
# Processing Record 40 of Set 14 | rundu
# Processing Record 41 of Set 14 | nimaparha
# Processing Record 42 of Set 14 | north platte
# Processing Record 43 of Set 14 | harper
# Processing Record 44 of Set 14 | grand baie
# Processing Record 45 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 46 of Set 14 | morehead
# Processing Record 47 of Set 14 | lingao
# Processing Record 48 of Set 14 | marrakesh
# Processing Record 49 of Set 14 | safford
# Processing Record 50 of Set 14 | iba
# Processing Record 1 of Set 15 | abu samrah
# Processing Record 2 of Set 15 | siderno
# Processing Record 3 of Set 15 | tambopata
# Processing Record 4 of Set 15 | umm kaddadah
# Processing Record 5 of Set 15 | ardistan
# City not found. Skipping...
# Processing Record 6 of Set 15 | nizhniy kuranakh
# Processing Record 7 of Set 15 | keti bandar
# Processing Record 8 of Set 15 | port keats
# Processing Record 9 of Set 15 | karpathos
# Processing Record 10 of Set 15 | aquin
# Processing Record 11 of Set 15 | benemerito de las americas
# Processing Record 12 of Set 15 | jumla
# Processing Record 13 of Set 15 | bara
# Processing Record 14 of Set 15 | ola
# Processing Record 15 of Set 15 | whittlesea
# Processing Record 16 of Set 15 | ikom
# Processing Record 17 of Set 15 | chhagalnaiya
# Processing Record 18 of Set 15 | merta
# Processing Record 19 of Set 15 | calvinia
# Processing Record 20 of Set 15 | farmington
# Processing Record 21 of Set 15 | caravelas
# Processing Record 22 of Set 15 | forio
# Processing Record 23 of Set 15 | hit
# Processing Record 24 of Set 15 | palabuhanratu
# City not found. Skipping...
# Processing Record 25 of Set 15 | amberley
# Processing Record 26 of Set 15 | moshny
# Processing Record 27 of Set 15 | qasigiannguit
# Processing Record 28 of Set 15 | lasa
# Processing Record 29 of Set 15 | san matias
# Processing Record 30 of Set 15 | macarthur
# Processing Record 31 of Set 15 | teneguiban
# City not found. Skipping...
# Processing Record 32 of Set 15 | san miguel
# Processing Record 33 of Set 15 | yenagoa
# Processing Record 34 of Set 15 | luanda
# Processing Record 35 of Set 15 | santa lucia
# Processing Record 36 of Set 15 | saravan
# Processing Record 37 of Set 15 | barreirinha
# Processing Record 38 of Set 15 | nhulunbuy
# Processing Record 39 of Set 15 | olenino
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 682

# %%
# Convert array of dictionaries to a pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
city_data_df.head(10)
# Out:
#                City      Lat       Lng  Max Temp Current Description  \
# 0             Erzin  36.9559   36.2000     79.47       broken clouds
# 1           Rikitea -23.1203 -134.9692     68.40     overcast clouds
# 2  Praia Da Vitoria  38.7333  -27.0667     74.34          few clouds
# 3         Guarapari -20.6667  -40.4975     69.89     overcast clouds
# 4      Saint George  37.1041 -113.5841     84.79           clear sky
# 5            Xining  36.6167  101.7667     61.72     overcast clouds
# 6   Puerto Colombia  10.9878  -74.9547     80.53     overcast clouds
# 7          Flinders -34.5833  150.8552     46.26           clear sky
# 8              Teya  60.3778   92.6267     46.08     overcast clouds
# 9            Aspros  40.9000   22.6309     83.98       broken clouds
#
#    Humidity  Cloudiness  Wind Speed Country
# 0        86          68        9.33      TR
# 1        73          93       12.97      PF
# 2        71          21        7.05      PT
# 3        74         100        7.74      BR
# 4        45           2        3.00      US
# 5        83          99        2.19      CN
# 6        78         100        3.67      CO
# 7        76           5       10.29      AU
# 8        72         100        3.18      RU
# 9        51          79        7.40      GR

# %%
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Current Description', 'Humidity',
#        'Cloudiness', 'Wind Speed', 'Country'],
#       dtype='object')

# %%
# Reorder the columns in the order you want them to appear.
new_column_order = ["City", "Country", "Lat",
                    "Lng", "Max Temp", "Humidity", 
                    "Cloudiness", "Wind Speed", 
                    "Current Description"] 

# Assign a new or the same DataFrame the new column order.
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0             Erzin      TR  36.9559   36.2000     79.47        86
# 1           Rikitea      PF -23.1203 -134.9692     68.40        73
# 2  Praia Da Vitoria      PT  38.7333  -27.0667     74.34        71
# 3         Guarapari      BR -20.6667  -40.4975     69.89        74
# 4      Saint George      US  37.1041 -113.5841     84.79        45
# 5            Xining      CN  36.6167  101.7667     61.72        83
# 6   Puerto Colombia      CO  10.9878  -74.9547     80.53        78
# 7          Flinders      AU -34.5833  150.8552     46.26        76
# 8              Teya      RU  60.3778   92.6267     46.08        72
# 9            Aspros      GR  40.9000   22.6309     83.98        51
#
#    Cloudiness  Wind Speed Current Description
# 0          68        9.33       broken clouds
# 1          93       12.97     overcast clouds
# 2          21        7.05          few clouds
# 3         100        7.74     overcast clouds
# 4           2        3.00           clear sky
# 5          99        2.19     overcast clouds
# 6         100        3.67     overcast clouds
# 7           5       10.29           clear sky
# 8         100        3.18     overcast clouds
# 9          79        7.40       broken clouds

# %%
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %%
# Create the output File (CSV)
output_data_file = "WeatherPy_Database.csv"
# Export the city_data into a csv
city_data_df.to_csv(output_data_file, index_label="City_ID")
